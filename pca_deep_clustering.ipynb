# %%
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms

from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, SpectralClustering
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from PIL import ImageFilter, Image

import numpy as np
import os
import warnings

warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.cluster._kmeans")

# %%
NUM_CLUSTERS = 5
USE_GPU = False
REDUCE_DIMENSIONS = True
PCA_COMPONENTS = 141

# %%
def load_feature_extractor(use_gpu):
    print("Cargando modelo ResNet50 preentrenado...")

    # Cargar ResNet50 preentrenado
    model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)

    modules = list(model.children())[:-1]
    feature_extractor = nn.Sequential(*modules)

    feature_extractor.eval()

    device = torch.device("cuda" if use_gpu and torch.cuda.is_available() else "cpu")
    feature_extractor.to(device)
    print(f"Usando dispositivo: {device}")

    return feature_extractor, device

# %%
def get_preprocess_transform():
    return transforms.Compose([
        transforms.Resize((224, 224)),  # Redimensionar a 224x224
        transforms.ToTensor(),
    ])

# %%
def extract_features(pil_image_list, model, device, preprocess):
    features = []
    model.eval()

    print(f"Extrayendo características de {len(pil_image_list)} imágenes...")
    with torch.no_grad():
        for i, img_pil in enumerate(pil_image_list):
            if img_pil.mode != "RGB":
                try:
                    img_pil = img_pil.convert("RGB")
                except Exception as e:
                    print(f"Advertencia: No se pudo convertir la imagen en el índice {i} a RGB. Se omitirá. Error: {e}")
                    continue

            try:
                img_tensor = preprocess(img_pil)
                img_batch = img_tensor.unsqueeze(0).to(device)
            except Exception as e:
                print(f"Advertencia: No se pudo preprocesar la imagen en el índice {i}. Se omitirá. Error: {e}")
                continue

            try:
                output = model(img_batch)
                feature_vector = torch.flatten(output, 1)
                features.append(feature_vector.cpu().numpy().squeeze())
            except Exception as e:
                print(f"Advertencia: No se pudieron extraer características para la imagen en el índice {i}. Se omitirá. Error: {e}")
                continue

            if (i + 1) % 50 == 0:
                print(f"  Procesadas {i + 1}/{len(pil_image_list)} imágenes...")

    print("Extracción de características completada.")
    if not features:
        print("Error: No se extrajeron características. Verifica la carga y preprocesamiento de imágenes.")
        return None
    return np.array(features)

# %%
def perform_clustering(features, n_clusters, use_pca=False, pca_components=None):
    if features is None or features.shape[0] < n_clusters:
        print("Error: No hay suficientes vectores de características válidos para realizar clustering.")
        return None, None

    print(f"Realizando clustering K-Means con k={n_clusters}...")

    if use_pca:
        if pca_components is None or pca_components >= features.shape[1] or pca_components <= 0:
            print(f"Advertencia: Valor inválido para pca_components ({pca_components}). Usando configuración predeterminada o se omitirá PCA.")
            pca = PCA(n_components=min(features.shape[0], features.shape[1] // 2), random_state=42)
        else:
            print(f"Aplicando PCA para reducir dimensiones a {pca_components}...")
            pca = PCA(n_components=pca_components, random_state=42)

        try:
            features_reduced = pca.fit_transform(features)
            print(f"Varianza explicada por PCA: {np.sum(pca.explained_variance_ratio_):.4f}")
            features_to_cluster = features_reduced
        except ValueError as e:
            print(f"Error durante PCA: {e}. Se realizará clustering sobre las características originales.")
            features_to_cluster = features
    else:
        features_to_cluster = features

    model = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    # model = AgglomerativeClustering(n_clusters=n_clusters, metric='euclidean', linkage='ward')
    try:
        cluster_labels = model.fit_predict(features_to_cluster)
        print("Clustering completado.")
        return cluster_labels, features_to_cluster
    except Exception as e:
        print(f"Error durante el clustering K-Means: {e}")
        return None, None

# %% [markdown]
# # Dataset Boold Cell

# %%
image_dir = "./storage/clean/blood_cell/segmenter"
pil_images = []
image_filenames = []

print(f"Cargando imágenes desde: {image_dir}")
valid_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tiff")
for filename in sorted(os.listdir(image_dir)):
    if filename.lower().endswith(valid_extensions):
        try:
            img_path = os.path.join(image_dir, filename)
            img = Image.open(img_path)
            pil_images.append(img)
            image_filenames.append(filename)
        except Exception as e:
            print(f"Advertencia: No se pudo cargar la imagen {filename}. Error: {e}")
print(f"{len(pil_images)} imágenes cargadas exitosamente.")

if not pil_images:
    print("No se cargaron imágenes. Terminando ejecución.")
    exit()

# 1. Cargar modelo y herramientas de preprocesamiento
feature_extractor, device = load_feature_extractor(use_gpu=USE_GPU)
preprocess_transform = get_preprocess_transform()

# 2. Extraer características
extracted_features = extract_features(pil_images, feature_extractor, device, preprocess_transform)

if extracted_features is not None:
    print(f"Forma de las características extraídas: {extracted_features.shape}")

    # 3. Realizar clustering
    cluster_labels, features_for_eval = perform_clustering(
        extracted_features,
        NUM_CLUSTERS,
        use_pca=REDUCE_DIMENSIONS,
        pca_components=PCA_COMPONENTS
    )

    # 4. Mostrar resultados
    if cluster_labels is not None:
        print("\n--- Resultados del Clustering ---")
        results = {}
        for i, label in enumerate(cluster_labels):
            if label not in results:
                results[label] = []
            img_identifier = image_filenames[i] if i < len(image_filenames) else f"Imagen {i}"
            results[label].append(img_identifier)

        print("\n--- Resumen de Clusters ---")
        for cluster_id in sorted(results.keys()):
            print(f"Cluster {cluster_id}: Contiene {len(results[cluster_id])} imágenes")

        if len(set(cluster_labels)) > 1 and len(cluster_labels) > len(set(cluster_labels)):
            try:
                silhouette_avg = silhouette_score(features_for_eval, cluster_labels)
                print(f"\nPuntaje Silhouette: {silhouette_avg:.4f}")
                print("(El puntaje Silhouette varía entre -1 y 1. Mayor es generalmente mejor.)")
            except Exception as e:
                print(f"\nNo se pudo calcular el Puntaje Silhouette: {e}")

            try:
                ch_score = calinski_harabasz_score(features_for_eval, cluster_labels)
                print(f"Índice Calinski-Harabasz (CH): {ch_score:.2f}")
                print("(Valores más altos indican clusters mejor definidos - más densos y mejor separados.)")
            except Exception as e:
                print(f"\nNo se pudo calcular el Índice Calinski-Harabasz: {e}")
        else:
            print("\nNo se puede calcular el Puntaje Silhouette (requiere >1 cluster y >N muestras).")

    else:
        print("No se pudo completar el clustering.")
else:
    print("La extracción de características falló. No se puede continuar con el clustering.")

for img in pil_images:
    if hasattr(img, "close"):
        img.close()
print("\nProcesamiento finalizado.")

# %% [markdown]
# # Dataset CIFAR

# %%
from torchvision.datasets import CIFAR10

# Cargar CIFAR-10
print("Cargando CIFAR-10 desde torchvision...")
dataset = CIFAR10(root="./data", train=False, download=True)

# Extraer imágenes PIL y etiquetas
pil_images = [img for img, _ in dataset]
image_filenames = [f"CIFAR10_img_{i}" for i in range(len(pil_images))]

# 1. Cargar modelo y herramientas de preprocesamiento
feature_extractor, device = load_feature_extractor(use_gpu=USE_GPU)
preprocess_transform = get_preprocess_transform()

# 2. Extraer características
extracted_features = extract_features(pil_images, feature_extractor, device, preprocess_transform)

if extracted_features is not None:
    print(f"Forma de las características extraídas: {extracted_features.shape}")

    # 3. Realizar clustering
    cluster_labels, features_for_eval = perform_clustering(
        extracted_features,
        NUM_CLUSTERS,
        use_pca=REDUCE_DIMENSIONS,
        pca_components=PCA_COMPONENTS
    )

    # 4. Mostrar resultados
    if cluster_labels is not None:
        print("\n--- Resultados del Clustering ---")
        results = {}
        for i, label in enumerate(cluster_labels):
            if label not in results:
                results[label] = []
            img_identifier = image_filenames[i] if i < len(image_filenames) else f"Imagen {i}"
            results[label].append(img_identifier)

        print("\n--- Resumen de Clusters ---")
        for cluster_id in sorted(results.keys()):
            print(f"Cluster {cluster_id}: Contiene {len(results[cluster_id])} imágenes")

        if len(set(cluster_labels)) > 1 and len(cluster_labels) > len(set(cluster_labels)):
            try:
                silhouette_avg = silhouette_score(features_for_eval, cluster_labels)
                print(f"\nPuntaje Silhouette: {silhouette_avg:.4f}")
                print("(El puntaje Silhouette varía entre -1 y 1. Mayor es generalmente mejor.)")
            except Exception as e:
                print(f"\nNo se pudo calcular el Puntaje Silhouette: {e}")

            try:
                ch_score = calinski_harabasz_score(features_for_eval, cluster_labels)
                print(f"Índice Calinski-Harabasz (CH): {ch_score:.2f}")
                print("(Valores más altos indican clusters mejor definidos - más densos y mejor separados.)")
            except Exception as e:
                print(f"\nNo se pudo calcular el Índice Calinski-Harabasz: {e}")
        else:
            print("\nNo se puede calcular el Puntaje Silhouette (requiere >1 cluster y >N muestras).")

    else:
        print("No se pudo completar el clustering.")
else:
    print("La extracción de características falló. No se puede continuar con el clustering.")

for img in pil_images:
    if hasattr(img, "close"):
        img.close()
print("\nProcesamiento finalizado.")
# Out:
# Cargando CIFAR-10 desde torchvision...
# Cargando modelo ResNet50 preentrenado...
# Usando dispositivo: cpu
# Extrayendo características de 10000 imágenes...
#   Procesadas 50/10000 imágenes...
#   Procesadas 100/10000 imágenes...
#   Procesadas 150/10000 imágenes...
#   Procesadas 200/10000 imágenes...
#   Procesadas 250/10000 imágenes...
#   Procesadas 300/10000 imágenes...
#   Procesadas 350/10000 imágenes...
#   Procesadas 400/10000 imágenes...
#   Procesadas 450/10000 imágenes...
#   Procesadas 500/10000 imágenes...
#   Procesadas 550/10000 imágenes...
#   Procesadas 600/10000 imágenes...
#   Procesadas 650/10000 imágenes...
#   Procesadas 700/10000 imágenes...
#   Procesadas 750/10000 imágenes...
#   Procesadas 800/10000 imágenes...
#   Procesadas 850/10000 imágenes...
#   Procesadas 900/10000 imágenes...
#   Procesadas 950/10000 imágenes...
#   Procesadas 1000/10000 imágenes...
#   Procesadas 1050/10000 imágenes...
#   Procesadas 1100/10000 imágenes...
#   Procesadas 1150/10000 imágenes...
#   Procesadas 1200/10000 imágenes...
#   Procesadas 1250/10000 imágenes...
#   Procesadas 1300/10000 imágenes...
#   Procesadas 1350/10000 imágenes...
#   Procesadas 1400/10000 imágenes...
#   Procesadas 1450/10000 imágenes...
#   Procesadas 1500/10000 imágenes...
#   Procesadas 1550/10000 imágenes...
#   Procesadas 1600/10000 imágenes...
#   Procesadas 1650/10000 imágenes...
#   Procesadas 1700/10000 imágenes...
#   Procesadas 1750/10000 imágenes...
#   Procesadas 1800/10000 imágenes...
#   Procesadas 1850/10000 imágenes...
#   Procesadas 1900/10000 imágenes...
#   Procesadas 1950/10000 imágenes...
#   Procesadas 2000/10000 imágenes...
#   Procesadas 2050/10000 imágenes...
#   Procesadas 2100/10000 imágenes...
#   Procesadas 2150/10000 imágenes...
#   Procesadas 2200/10000 imágenes...
#   Procesadas 2250/10000 imágenes...
#   Procesadas 2300/10000 imágenes...
#   Procesadas 2350/10000 imágenes...
#   Procesadas 2400/10000 imágenes...
#   Procesadas 2450/10000 imágenes...
#   Procesadas 2500/10000 imágenes...
#   Procesadas 2550/10000 imágenes...
#   Procesadas 2600/10000 imágenes...
#   Procesadas 2650/10000 imágenes...
#   Procesadas 2700/10000 imágenes...
#   Procesadas 2750/10000 imágenes...
#   Procesadas 2800/10000 imágenes...
#   Procesadas 2850/10000 imágenes...
#   Procesadas 2900/10000 imágenes...
#   Procesadas 2950/10000 imágenes...
#   Procesadas 3000/10000 imágenes...
#   Procesadas 3050/10000 imágenes...
#   Procesadas 3100/10000 imágenes...
#   Procesadas 3150/10000 imágenes...
#   Procesadas 3200/10000 imágenes...
#   Procesadas 3250/10000 imágenes...
#   Procesadas 3300/10000 imágenes...
#   Procesadas 3350/10000 imágenes...
#   Procesadas 3400/10000 imágenes...
#   Procesadas 3450/10000 imágenes...
#   Procesadas 3500/10000 imágenes...
#   Procesadas 3550/10000 imágenes...
#   Procesadas 3600/10000 imágenes...
#   Procesadas 3650/10000 imágenes...
#   Procesadas 3700/10000 imágenes...
#   Procesadas 3750/10000 imágenes...
#   Procesadas 3800/10000 imágenes...
#   Procesadas 3850/10000 imágenes...
#   Procesadas 3900/10000 imágenes...
#   Procesadas 3950/10000 imágenes...
#   Procesadas 4000/10000 imágenes...
#   Procesadas 4050/10000 imágenes...
#   Procesadas 4100/10000 imágenes...
#   Procesadas 4150/10000 imágenes...
#   Procesadas 4200/10000 imágenes...
#   Procesadas 4250/10000 imágenes...
#   Procesadas 4300/10000 imágenes...
#   Procesadas 4350/10000 imágenes...
#   Procesadas 4400/10000 imágenes...
#   Procesadas 4450/10000 imágenes...
#   Procesadas 4500/10000 imágenes...
#   Procesadas 4550/10000 imágenes...
#   Procesadas 4600/10000 imágenes...
#   Procesadas 4650/10000 imágenes...
#   Procesadas 4700/10000 imágenes...
#   Procesadas 4750/10000 imágenes...
#   Procesadas 4800/10000 imágenes...
#   Procesadas 4850/10000 imágenes...
#   Procesadas 4900/10000 imágenes...
#   Procesadas 4950/10000 imágenes...
#   Procesadas 5000/10000 imágenes...
#   Procesadas 5050/10000 imágenes...
#   Procesadas 5100/10000 imágenes...
#   Procesadas 5150/10000 imágenes...
#   Procesadas 5200/10000 imágenes...
#   Procesadas 5250/10000 imágenes...
#   Procesadas 5300/10000 imágenes...
#   Procesadas 5350/10000 imágenes...
#   Procesadas 5400/10000 imágenes...
#   Procesadas 5450/10000 imágenes...
#   Procesadas 5500/10000 imágenes...
#   Procesadas 5550/10000 imágenes...
#   Procesadas 5600/10000 imágenes...
#   Procesadas 5650/10000 imágenes...
#   Procesadas 5700/10000 imágenes...
#   Procesadas 5750/10000 imágenes...
#   Procesadas 5800/10000 imágenes...
#   Procesadas 5850/10000 imágenes...
#   Procesadas 5900/10000 imágenes...
#   Procesadas 5950/10000 imágenes...
#   Procesadas 6000/10000 imágenes...
#   Procesadas 6050/10000 imágenes...
#   Procesadas 6100/10000 imágenes...
#   Procesadas 6150/10000 imágenes...
#   Procesadas 6200/10000 imágenes...
#   Procesadas 6250/10000 imágenes...
#   Procesadas 6300/10000 imágenes...
#   Procesadas 6350/10000 imágenes...
#   Procesadas 6400/10000 imágenes...
#   Procesadas 6450/10000 imágenes...
#   Procesadas 6500/10000 imágenes...
#   Procesadas 6550/10000 imágenes...
#   Procesadas 6600/10000 imágenes...
#   Procesadas 6650/10000 imágenes...
#   Procesadas 6700/10000 imágenes...
#   Procesadas 6750/10000 imágenes...
#   Procesadas 6800/10000 imágenes...
#   Procesadas 6850/10000 imágenes...
#   Procesadas 6900/10000 imágenes...
#   Procesadas 6950/10000 imágenes...
#   Procesadas 7000/10000 imágenes...
#   Procesadas 7050/10000 imágenes...
#   Procesadas 7100/10000 imágenes...
#   Procesadas 7150/10000 imágenes...
#   Procesadas 7200/10000 imágenes...
#   Procesadas 7250/10000 imágenes...
#   Procesadas 7300/10000 imágenes...
#   Procesadas 7350/10000 imágenes...
#   Procesadas 7400/10000 imágenes...
#   Procesadas 7450/10000 imágenes...
#   Procesadas 7500/10000 imágenes...
#   Procesadas 7550/10000 imágenes...
#   Procesadas 7600/10000 imágenes...
#   Procesadas 7650/10000 imágenes...
#   Procesadas 7700/10000 imágenes...
#   Procesadas 7750/10000 imágenes...
#   Procesadas 7800/10000 imágenes...
#   Procesadas 7850/10000 imágenes...
#   Procesadas 7900/10000 imágenes...
#   Procesadas 7950/10000 imágenes...
#   Procesadas 8000/10000 imágenes...
#   Procesadas 8050/10000 imágenes...
#   Procesadas 8100/10000 imágenes...
#   Procesadas 8150/10000 imágenes...
#   Procesadas 8200/10000 imágenes...
#   Procesadas 8250/10000 imágenes...
#   Procesadas 8300/10000 imágenes...
#   Procesadas 8350/10000 imágenes...
#   Procesadas 8400/10000 imágenes...
#   Procesadas 8450/10000 imágenes...
#   Procesadas 8500/10000 imágenes...
#   Procesadas 8550/10000 imágenes...
#   Procesadas 8600/10000 imágenes...
#   Procesadas 8650/10000 imágenes...
#   Procesadas 8700/10000 imágenes...
#   Procesadas 8750/10000 imágenes...
#   Procesadas 8800/10000 imágenes...
#   Procesadas 8850/10000 imágenes...
#   Procesadas 8900/10000 imágenes...
#   Procesadas 8950/10000 imágenes...
#   Procesadas 9000/10000 imágenes...
#   Procesadas 9050/10000 imágenes...
#   Procesadas 9100/10000 imágenes...
#   Procesadas 9150/10000 imágenes...
#   Procesadas 9200/10000 imágenes...
#   Procesadas 9250/10000 imágenes...
#   Procesadas 9300/10000 imágenes...
#   Procesadas 9350/10000 imágenes...
#   Procesadas 9400/10000 imágenes...
#   Procesadas 9450/10000 imágenes...
#   Procesadas 9500/10000 imágenes...
#   Procesadas 9550/10000 imágenes...
#   Procesadas 9600/10000 imágenes...
#   Procesadas 9650/10000 imágenes...
#   Procesadas 9700/10000 imágenes...
#   Procesadas 9750/10000 imágenes...
#   Procesadas 9800/10000 imágenes...
#   Procesadas 9850/10000 imágenes...
#   Procesadas 9900/10000 imágenes...
#   Procesadas 9950/10000 imágenes...
#   Procesadas 10000/10000 imágenes...
# Extracción de características completada.
# Forma de las características extraídas: (10000, 2048)
# Realizando clustering K-Means con k=5...
# Aplicando PCA para reducir dimensiones a 141...
# Varianza explicada por PCA: 0.8983
# Clustering completado.
#
# --- Resultados del Clustering ---
#
# --- Resumen de Clusters ---
# Cluster 0: Contiene 2313 imágenes
# Cluster 1: Contiene 1875 imágenes
# Cluster 2: Contiene 2407 imágenes
# Cluster 3: Contiene 919 imágenes
# Cluster 4: Contiene 2486 imágenes
#
# Puntaje Silhouette: 0.0646
# (El puntaje Silhouette varía entre -1 y 1. Mayor es generalmente mejor.)
# Índice Calinski-Harabasz (CH): 652.64
# (Valores más altos indican clusters mejor definidos - más densos y mejor separados.)
#
# Procesamiento finalizado.
